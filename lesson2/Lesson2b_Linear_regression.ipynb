# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
# from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
import pickle as pkl

# %% [markdown]
# <div dir="rtl">
#
# ###    להלן הדוגמא הבאה: במפעל להכנת זכוכיות משתמשים בנַתְרָן פַּחְמָתִי. חומר זה בכמות גבוהה מדי יכול להיות מסוכן. נרצה לבדוק האם שיעור הנתרן הפחמתי משפיע על רמת זיהום האוויר ברצפת הייצור. רמת זיהום היא דירוג רציף הנע בין 0 ל-50. נרצה לראות האם שיעור הנתרן הפחמתי אכן משפיע ואיך.

# %%
num_points = 120
x_vals = np.linspace(0,1,num_points)
y_vals_trans_1 = pkl.load(open('../pkl/y_vals_trans_1.pkl', 'rb'))

# %%
plt.figure()
plt.title('Non-linear example')
plt.xlabel('Sodium carbonate', fontsize= 24)
plt.ylabel('Air pollution', fontsize= 24)
plt.scatter(x_vals, y_vals_trans_1)
plt.show()

# %% [markdown]
# <div dir="rtl">  בוא נראה מה קורה אם אנחנו מתעלמים מחוסר הליניאריות.

# %%
# Assuming X_train and y_train are your training data
x_vals1 = sm.add_constant(x_vals)  # Add a constant (intercept) term to the features
## If we don't add it, the intercept will be 0.
# Create a linear regression model

df_data = pd.DataFrame(np.append(x_vals1, y_vals_trans_1.reshape( y_vals_trans_1.shape[0],1), axis = 1), columns = ['intercept', 'Sodium', 'Pollution'])

model = sm.OLS(df_data['Pollution'], df_data[['intercept', 'Sodium']])
# Fit the model
results = model.fit()
# Print summary statistics, including p-values for each coefficient
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Pollution   R-squared:                       0.821
# Model:                            OLS   Adj. R-squared:                  0.820
# Method:                 Least Squares   F-statistic:                     541.7
# Date:                Tue, 04 Nov 2025   Prob (F-statistic):           6.40e-46
# Time:                        11:33:50   Log-Likelihood:                -329.73
# No. Observations:                 120   AIC:                             663.5
# Df Residuals:                     118   BIC:                             669.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     -4.4595      0.691     -6.454      0.000      -5.828      -3.091
# Sodium        27.7973      1.194     23.275      0.000      25.432      30.162
# ==============================================================================
# Omnibus:                       24.918   Durbin-Watson:                   0.189
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               33.234
# Skew:                           1.113   Prob(JB):                     6.07e-08
# Kurtosis:                       4.300   Cond. No.                         4.36
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
df_data.head()
# Out:
#    intercept    Sodium  Pollution
# 0        1.0  0.000000   1.038848
# 1        1.0  0.008403   1.105293
# 2        1.0  0.016807   1.117831
# 3        1.0  0.025210   1.229687
# 4        1.0  0.033613   1.248965

# %%
plt.figure()
plt.title('Non-linear example', fontsize= 24)
plt.xlabel('Sodium carbonate', fontsize= 24)
plt.ylabel('Air pollution', fontsize= 24)
plt.scatter(x_vals, y_vals_trans_1)
plt.plot(x_vals, results.predict(x_vals1), color = 'red')
plt.show()

# %% [markdown]
# ## Transforming the data

# %% [markdown]
# <div dir="rtl">  במקום להשתמש בערכים האמיתיים של המשתנה המוסבר ננסה לעשות איזשהו טרנספורמציה ואולי נצליח לעשות למצוא קשר יותר ליניארי. להלן מספר טרנספורמציות אפשריות.

# %% [markdown]
# 1. $Ln(Y)$ or $Log(Y)$
# 2. $Exp(Y)$
# 3. $Y^{0.5}$
# 4. $Y^2$
#
# The model is:
#
# $$ Ln(\hat{Y}) = \hat{b_0} + \hat{b_1} X_1 $$
#
# Or,
#
# $$ \hat{Y} = Exp(\hat{b_0} + \hat{b_1} X_1) $$

# %% [markdown]
# <div dir="rtl"> נתחיל עם טרנספורמציה של Ln.

# %%
log_Y_trans_1 = np.log(y_vals_trans_1)
plt.figure()
plt.title('After transformation', fontsize= 24)
plt.xlabel('Sodium carbonate', fontsize= 24)
plt.ylabel('Log(Air pollution)', fontsize= 24)
plt.scatter(x_vals, log_Y_trans_1)
plt.show()

# %%
# Create a linear regression model
df_data1 = pd.DataFrame(np.append(x_vals1, log_Y_trans_1.reshape( log_Y_trans_1.shape[0],1), axis = 1), columns = ['intercept', 'Sodium', 'log_Pollution'])
df_data1.head()
# Out:
#    intercept    Sodium  log_Pollution
# 0        1.0  0.000000       0.038113
# 1        1.0  0.008403       0.100111
# 2        1.0  0.016807       0.111390
# 3        1.0  0.025210       0.206760
# 4        1.0  0.033613       0.222316

# %%
model_trans1 = sm.OLS(df_data1['log_Pollution'], df_data1[['intercept', 'Sodium']])
# Fit the model
results_trans1 = model_trans1.fit()
# Print summary statistics, including p-values for each coefficient
print(results_trans1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          log_Pollution   R-squared:                       0.991
# Model:                            OLS   Adj. R-squared:                  0.991
# Method:                 Least Squares   F-statistic:                 1.304e+04
# Date:                Tue, 04 Nov 2025   Prob (F-statistic):          1.17e-122
# Time:                        11:33:50   Log-Likelihood:                 109.46
# No. Observations:                 120   AIC:                            -214.9
# Df Residuals:                     118   BIC:                            -209.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0092      0.018      0.516      0.607      -0.026       0.044
# Sodium         3.5103      0.031    114.211      0.000       3.449       3.571
# ==============================================================================
# Omnibus:                        0.408   Durbin-Watson:                   1.972
# Prob(Omnibus):                  0.815   Jarque-Bera (JB):                0.201
# Skew:                          -0.094   Prob(JB):                        0.904
# Kurtosis:                       3.070   Cond. No.                         4.36
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# <div dir="rtl">
#
# ###     אפשר לראות שעכשיו המדד של $R^2$ גדל משמעותית ל 0.991.

# %%
plt.figure()
plt.title('After transformation', fontsize= 24)
plt.xlabel('Sodium carbonate', fontsize= 24)
plt.ylabel('Log Air pollution', fontsize= 24)
plt.scatter(x_vals, log_Y_trans_1)
plt.plot(x_vals, results_trans1.predict(x_vals1), color = 'red')
plt.show()

# %% [markdown]
# <div dir="rtl"> מה היה קורה אילו היינו עושים טרנספורמציה אחרת?
# ננסה לעשות עכשיו טרנספורמצית שורש, כלומר:
#
# $$ \sqrt{y} = b_0 +b_1 X_1$$

# %%
sqrt_Y_trans_1 = y_vals_trans_1**0.5
plt.figure()
plt.title('After transformation', fontsize= 24)
plt.xlabel('Sodium carbonate', fontsize= 24)
plt.ylabel('sqrt Air pollution', fontsize= 24)
plt.scatter(x_vals, sqrt_Y_trans_1)
plt.show()

# %%
# Create a linear regression model
model_trans2 = sm.OLS(sqrt_Y_trans_1, x_vals1)
# Fit the model
results_trans2 = model_trans2.fit()
# Print summary statistics, including p-values for each coefficient
print(results_trans2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.941
# Model:                            OLS   Adj. R-squared:                  0.941
# Method:                 Least Squares   F-statistic:                     1891.
# Date:                Tue, 04 Nov 2025   Prob (F-statistic):           1.76e-74
# Time:                        11:33:51   Log-Likelihood:                -38.487
# No. Observations:                 120   AIC:                             80.97
# Df Residuals:                     118   BIC:                             86.55
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.4541      0.061      7.443      0.000       0.333       0.575
# x1             4.5858      0.105     43.484      0.000       4.377       4.795
# ==============================================================================
# Omnibus:                       12.156   Durbin-Watson:                   0.348
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               12.780
# Skew:                           0.774   Prob(JB):                      0.00168
# Kurtosis:                       3.402   Cond. No.                         4.36
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# <div dir="rtl"> נראה שזה עדיף על פני המקור אבל פחות טוב מה$Ln$.

# %%
plt.figure()
plt.title('After transformation', fontsize= 24)
plt.xlabel('Sodium carbonate', fontsize= 24)
plt.ylabel('sqrt Air pollution', fontsize= 24)
plt.scatter(x_vals, sqrt_Y_trans_1)
plt.plot(x_vals, results_trans2.predict(x_vals1), color = 'red')
plt.show()

# %% [markdown]
# <div dir="rtl">
#
# ### אחרי שעשינו טרספורמציה איך אנחנו עושים תחזית? הרי המודל חוזה ערכים של $Ln(\hat{Y})$ ולא ערכים של $\hat{Y}$.
#
# ### תחילה נחזה את ערכי ה$Ln(\hat{Y})$ ואז נעשה את הטרנפורמציה ההפוכה.

# %% [markdown]
# 1. $Ln(\hat{Y}) = \hat{b_0} + \hat{b_1} X_1$
# 2. $\hat{Y} = Exp(Ln(\hat{Y}))$

# %% [markdown]
# <div dir="rtl">
#
# ###     למשל, ננסה לחזות מהי רמת הזיהום עבור שיעור נתרן פחמני של 0.4.

# %%
lny = results_trans1.predict(np.array([1, 0.4]))
lny
# Out:
# array([1.4132882])

# %% [markdown]
# <div dir="rtl"> ועכשיו נעשה טרנספורמציה

# %% [markdown]
# ## $$ log(Exp(x)) = Exp(log(x)) = x $$
#
# ## $$ (\sqrt(x))^2 = \sqrt{x^2} = x $$
#
# ## $$ ((x)^{\frac{1}{n}})^n = ((x)^n)^{\frac{1}{n}}   = x$$

# %%
y = np.exp(lny)
y
# Out:
# array([4.10944588])

# %% [markdown]
# <div dir="rtl"> כלומר כאשר שיעור הנתרן הוא 0.4 רמת הזיהום היא 4.1.
# עכשיו ננסה לצייר את רמת הזיהום עבור כל הערכים האפשריים של נתרן פחמני.

# %%
plt.figure()
plt.title('The fitted model after transformation', fontsize= 24)
plt.xlabel('Sodium carbonate', fontsize= 24)
plt.ylabel('Air pollution', fontsize= 24)
plt.scatter(x_vals, y_vals_trans_1)
plt.plot(x_vals, np.exp(results_trans1.predict(x_vals1)), color = 'red')
plt.show()

# %% [markdown]
# <div dir="rtl">
#
# ###    שאלה: ידוע כי יש תקנת בטיחות שאסור לעבור זיהום רמה 10. מהו שיעור הכמות המקסימלית של נתרן פחמני בו ניתן להשתמש במפעל?
#
# ### נסתכל קודם גרפית:

# %%
plt.figure()
plt.title('The fitted model after transformation', fontsize= 24)
plt.xlabel('Sodium carbonate', fontsize= 24)
plt.ylabel('Air pollution', fontsize= 24)
plt.scatter(x_vals, y_vals_trans_1)
plt.plot(x_vals, np.exp(results_trans1.predict(x_vals1)), color = 'red')
plt.plot(x_vals, 10*np.ones(x_vals.shape[0]), color = 'black')
plt.scatter(0.653, 10, color = 'green', s=222, edgecolors= "black")
plt.show()

# %% [markdown]
# $$ Log(10) = 0.0092+3.5103*X_1 $$
#
# $$ 10 = e^{0.0092 +  3.5103*X_1 } $$
#
# $$ Ln(10) = 0.0092 + 3.5103*X_1 $$
#
# $$ \frac{Ln(10)-0.0092}{3.5103} = X_1 $$
#
# $$ X_1 =  0.653$$

# %%
import numpy as np
## The actual computation
(np.log(10)-0.0092)/3.5103
# Out:
# 0.6533302261897974
