# %% [markdown]
# <div style="background:#e0f4ff; border:2px solid #0077b6; border-radius:12px; padding:20px 24px;
#             direction:ltr; text-align:left;">
#
#   <h2 style="margin:4px 0 14px 0; font-size:48px; font-weight:700; color:#004c70;">
#     Regression Course
#   </h2>
#
#   <div style="height:1px; background:#cbeafb; margin:4px 0 18px 0;"></div>
#
#   <div style="font-size:26px; color:#0a5773; font-weight:600; margin:0 0 10px 0;">
#     Introduction to polynomial regression
#   </div>
#
#   <span style="display:inline-block; font-size:18px; font-weight:600; color:#0a5773;
#                background:#d9effc; border:1px solid #86c4e8; border-radius:999px; padding:6px 12px;">
#     Exercise no. 4
#   </span>
#
# </div>

# %% [markdown]
# <div dir="rtl" style="background:#f7fbff; border:2px solid #0077b6; border-radius:14px; padding:16px; line-height:1.6; text-align:right;">
#
#   <div style="font-size:180%; font-weight:700; margin-bottom:6px;">
#     זרימת השיעורים
#   </div>
#
#   <div style="font-size:110%; margin-bottom:10px;">
#     <b>המוטיבציה הכללית:</b> לבנות מודל שמקשר בין משתנים מסבירים למשתנה מוסבר, כדי <u>לנבא</u> ולהבין <u>השפעה שולית</u> של כל מסביר, תוך בדיקת התאמה והנחות המודל.
#   </div>
#
#   <hr style="border:none; border-top:1px solid #c9e7ff; margin:10px 0;">
#
#   <div style="margin-bottom:8px;">
#     <div style="font-weight:700; font-size:120%; margin-bottom:4px;">שיעור 1 - רגרסיה ליניארית פשוטה</div>
#     <ul style="margin:0 18px 0 0; padding:0;">
#       <li><b>משוואה ופרמטרים:</b>  \( y_i = \beta_0 + \beta_1 x_i + \varepsilon_i \) — שינוי של יחידה ב-\(x\) משנה את תוחלת \(y\) ב-\(\beta_1\).</li>
#       <li><b>OLS (ריבועים פחותים):</b> ממזערים \( \sum (y_i-\hat y_i)^2 \) ומקבלים אומדנים סגורים ל-\(\hat\beta\).</li>
#       <li><b>חותך:</b> מוסיפים עמודת אחדים \( \mathbf{1}_n \) כדי לאמוד \(\beta_0\).</li>
#       <li><b>מדד טיב התאמה \(R^2\):</b> יחס שונות מוסברת; קרבה בין \(y\) ל-\(\hat y\).</li>
#       <li><b>הנחות המודל:</b> ליניאריות, תוחלת שגיאה 0, הומוסקדסטיות, אי-תלות, נורמליות (להסקה).</li>
#       <li><b>מבחני השערות:</b> t לכל \(\beta_j\), ו-F להשוואת מודלים; שימוש ב-p-value ורווחי סמך (הסקה מתוך הסיכום מודל).</li>
#     </ul>
#   </div>
#
#   <div style="margin-bottom:8px;">
#     <div style="font-weight:700; font-size:120%; margin-bottom:4px;">שיעור 2 - טרנספורמציות על המשתנה המוסבר ולמה OLS</div>
#     <ul style="margin:0 18px 0 0; padding:0;">
#       <li><b>למה OLS?</b> תחת הנחות גאוס-מרקוב — BLUE: האומדן הליניארי הבלתי מוטה בעלי שונות מינימלית; פשוט ופרשני.</li>
#       <li><b>טרנספורמציות על \(Y\):</b> (לוג/ \( y^n\) וכו') לקידום ליניאריות, ייצוב שונות והתפלגות; משפרות התאמה כשהקשר לא ליניארי בקנה מידה המקורי.</li>
#       <li><b>זהירות בפרשנות:</b> טרנספורמציה משנה יחידות ומשמעות המקדמים; מומלץ להציג ניבויים גם בסקאלה המקורית (inversion).</li>
#     </ul>
#   </div>
#
#   <div>
#     <div style="font-weight:700; font-size:120%; margin-bottom:4px;">שיעור 3 - רגרסיה מרובת משתנים</div>
#     <ul style="margin:0 18px 0 0; padding:0;">
#     <li><b>מוטיבציה</b> בעולם האמיתי פועלים כמה גורמים בו־זמנית; נרצה למדוד ולהפריד את התרומות שלהם, לשפר ניבוי, ולהקטין הטיות</li>
# <li><b>מה זה אומר?</b> רגרסיה מרובת משתנים מאמדת את \(Y\) כצירוף ליניארי של כמה משתנים מסבירים; כל מקדם \(\beta_j\) מתפרש כשינוי הצפוי ב-\(Y\) עבור עלייה של יחידה ב-\(X_j\) בהינתן ששאר המסבירים קבועים.</li>
#   </ul>
# </div>
#
#
# <div style="background-color:#e0f4ff; border:2px solid #0077b6; border-radius:12px; padding:10px 10px;">
#     <div style="font-weight:700; font-size:120%; margin-bottom:4px;">היום - מבוא לרגרסיה פולינומיאלית</div>
#     <ul style="margin:0 18px 0 0; padding:0;">
#     <li><b>מוטיבציה</b> </li>
# <li><b>רעיון כללי</b> </li>
# <li><b>בחירת פולינום אופטימלי</b>
#             </li>
# <li><b>מדדים :  $Adjusted R², AIC, BIC.$</b>
#          </li>
#   </ul>
#
# </div>

# %% [markdown]
# <div style="background:#e0f4ff; border:2px solid #0077b6; border-radius:12px; padding:20px 24px;
#             direction:ltr; text-align:center;">
#   <h2 style="margin:-10px 0 -10px 10; font-size:48px; font-weight:700; color:#004c70;">
# kahoot!
#  </h2>

# %% [markdown]
# <div style="background:#e0f4ff; border:2px solid #0077b6; border-radius:12px; padding:20px 24px;
#             direction:ltr; text-align:right;">
#
#   <h2 style="margin:4px 0 14px 0; font-size:48px; font-weight:700; color:#004c70;">
#     מוטיבציה
#   </h2>
#
#   <div style="height:1px; background:#cbeafb; margin:4px 0 18px 0;"></div>
#
# <div dir="rtl"
#   <div style="font-size:16px; color:#0a5773; font-weight:600; margin:0 0 10px 0;">
#     ברגרסיה ליניארית רגילה אנחנו מניחים שקיים קשר בין המשתנים המסבירים 𝑋
#  לבין משתנה המטרה
# 𝑌.<br>
# במציאות ראינו שיש קשרים שהם לא בהכרח לינאריים ויתכן שיהיו עיקולים, פיקים ושיפועים שמשתנה לאורך הטווח. <br>
#
# <div dir="rtl"
#
# רגרסיה פולינומית מאפשרת לנו **להישאר בעולם של OLS** (מודל לינארי במקדמים) ולהעשיר את המודל כך שיוכל לתפוס **קשרים לא לינאריים** - על ידי הוספת חזקות של $X$ (ולפעמים גם אינטראקציות בין משתנים שעל זה נדבר בשבוע הבא). <br>
#
#   </div>

# %% [markdown]
# <div style="background:#e0f4ff; border:2px solid #0077b6; border-radius:12px; padding:20px 24px;
#             direction:ltr; text-align:right;">
#
#   <h2 style="margin:4px 0 14px 0; font-size:48px; font-weight:700; color:#004c70;">
#     דוגמאות
#   </h2>
#
#   <div style="height:1px; background:#cbeafb; margin:4px 0 18px 0;"></div>
#
# <div dir="rtl"
#   <div style="font-size:16px; color:#0a5773; font-weight:600; margin:0 0 10px 0;">
#
# - טמפרטורה של מכונה לפי זמן עבודה – אולי עולה מהר, מתייצבת, ואז שוב עולה.
# - סיכון לתאונה לפי גיל נהג – גבוה בצעירים, יורד באמצע החיים, ואולי עולה שוב בגיל מבוגר.
# - תפוקה של מכונה מול כמות חומר – עולה עד נקודה מסוימת ואז נופלת.
#   </div>

# %% [markdown]
# <div style="background:#e0f4ff; border:2px solid #0077b6; border-radius:12px; padding:20px 24px;
#             direction:ltr; text-align:right;">
#
#   <h2 style="margin:4px 0 14px 0; font-size:48px; font-weight:700; color:#004c70;">
#     הרעיון
#   </h2>
#
#   <div style="height:1px; background:#cbeafb; margin:4px 0 18px 0;"></div>
#
# <div dir="rtl"
#   <div style="font-size:16px; color:#0a5773; font-weight:600; margin:0 0 10px 0;">
# <div dir="rtl"
#
# במקרים כאלה, ישר אחד לא מספיק. <br>
# במקום להתייאש מ"קו ישר שלא מתאים", אנחנו מגדירים משתנים חדשים כמו $X^2 , X^3 , ...$ מתייחסים אליהם כאל "משתנים מסבירים נוספים", ועדיין מחשבים את המקדמים בעזרת **OLS** רגיל. <br>
# היתרון - מודל גמיש יותר, שעדיין נשאר במסגרת מתמטית מוכרת, עם כל התכונות של רגרסיה לינארית.
#   </div>

# %% [markdown]
# <div style="background:#e0f4ff; border:2px solid #0077b6; border-radius:12px; padding:20px 24px;
#             direction:ltr; text-align:right;">
#
#   <h2 style="margin:4px 0 14px 0; font-size:48px; font-weight:700; color:#004c70;">
#     ?"איך זה עדיין “רגרסיה ליניארית
#   </h2>
#
#   <div style="height:1px; background:#cbeafb; margin:4px 0 18px 0;"></div>
#
#   <div style="font-size:16px;text-align:right; color:#0a5773; font-weight:600; margin:0 0 10px 0;">
# <div dir="rtl"
#
# אם ניצור עמודות חדשות: <br>
# $ f(x_1) = x^1 $ <br>
# $ f(x_2) = x^2 $ <br>
# $ f(x_3) = x^3 $ <br>
# $ f(x_4) = x^4 $
#
# <div dir="rtl"
#
# ואז נבנה מודל :
#
# $$ Y = \beta_0 + \beta_1f(x_1) + \beta_2f(x_2) + \beta_3f(x_3)+ b_4f(x_4)   $$
#
# <div dir="rtl"
#
# זה מודל ליניארי רגיל לגמרי (OLS), רק שהפיצ’רים שלנו הם $x, x^2,x^3,x^4$
# מבחינת Python / statsmodels / sklearn – זה עוד מודל ליניארי, ולכן:
# - משתמשים באותה שיטת אומדן $OLS$
# - אותם מדדים $R^2$ , $MSE$, שאריות וכ'ו
#   </div>

# %% [markdown]
# <div style="background:#e0f4ff; border:2px solid #0077b6; border-radius:12px; padding:20px 24px;
#             direction:ltr; text-align:right;">
#
#   <h2 style="margin:4px 0 14px 0; font-size:48px; font-weight:700; color:#004c70;">
#     יתרונות וחסרונות
#   </h2>
#
#   <div style="height:1px; background:#cbeafb; margin:4px 0 18px 0;"></div>
#
#   <div style="font-size:26px;text-align:right; color:#0a5773; font-weight:600; margin:0 0 10px 0;">
# <div dir="rtl"
#  <br>
# יתרונות:
# <div style="font-size:16px;text-align:right; color:#0a5773; font-weight:600; margin:0 0 10px 0;">
# 1. מאפשר לתפוס קשרים לא ליניאריים בלי לעבור למודלים “כבדים” יותר (Trees, NN וכו’).<br>
# 2. עדיין פשוט ליישום. <br>
# 3. נשארים בעולם המוכר של OLS, שאריות,
# $𝑅^2$ , וכו’.<br>
# <br>
#   <div style="font-size:26px;text-align:right; color:#0a5773; font-weight:600; margin:0 0 10px 0;">
# <div dir="rtl"
# <br>
# חסרונות:
#
# <div style="font-size:16px;text-align:right; color:#0a5773; font-weight:600; margin:0 0 10px 0;">
# 1. אוברפיטינג: פולינום מדרגה גבוהה יכול “להתפתל” יתר על המידה ולהיצמד לרעש.<br>
# 2. אקסטרפולציה גרועה: מחוץ לטווח הנתונים הפולינום יכול “לעוף” למעלה או למטה בצורה קיצונית.<br>
# 3. רגיש מאוד לסקיילינג (מומלץ לעשות סטנדרטיזציה ל-x לפני בניית פולינום גבוה).
#   </div>

# %% [markdown]
# <div style="background:#e0f4ff; border:2px solid #0077b6; border-radius:12px; padding:20px 24px;
#             direction:ltr; text-align:right;">
#
#   <h2 style="margin:4px 0 14px 0; font-size:48px; font-weight:700; color:#004c70;">
#     תזכורת על טרנספורמציות
#   </h2>
#
#   <div style="height:1px; background:#cbeafb; margin:4px 0 18px 0;"></div>
#
# <div dir="rtl"
#   <div style="font-size:22px; color:#0a5773; font-weight:600; margin:0 0 10px 0;">
# <div dir="rtl"
#
# טרנספורמציה על 𝑌
#
#   </div>

# %%
import numpy as np
import matplotlib.pyplot as plt

# נתונים פשוטים להמחשה
x = np.linspace(0, 10, 100)

# מודל ליניארי על y^2
y_squared_hat = 4 + 2*x  # זה קו ישר במרחב של y^2

# החזרה לסקייל המקורי
y_hat = np.sqrt(y_squared_hat)

# גרף 1 – עולם ההתמרה (y^2)
plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(x, y_squared_hat, color='royalblue', linewidth=3)
plt.title("The world of transformation – y² = 4 + 2x", fontsize=14)
plt.xlabel("x")
plt.ylabel("y²", rotation=0, labelpad= 10)
plt.grid(True)
# גרף 2 – העולם המקורי (y = √(4+2x))
plt.subplot(1,2,2)
plt.plot(x, y_hat, color='darkorange', linewidth=3)
plt.title("The original world – y = √(4 + 2x)", fontsize=14)
plt.xlabel("x")
plt.ylabel("y", rotation=0, labelpad= 10)
plt.grid(True)

plt.suptitle("A straight line in y² space becomes a curve when returned to y space", fontsize=16, fontweight='bold')
plt.tight_layout(rect=[0, 0, 1, 0.94])
plt.show()

# %% [markdown]
# <div style="background:#e0f4ff; border:2px solid #0077b6; border-radius:12px; padding:20px 24px;
#             direction:ltr; text-align:right;">
#
#   <h2 style="margin:4px 0 14px 0; font-size:48px; font-weight:700; color:#004c70;">
#     רגרסיה פולינומית
#   </h2>
#
#   <div style="height:1px; background:#cbeafb; margin:4px 0 18px 0;"></div>
#
# <div dir="rtl"
#   <div style="font-size:22px; color:#0a5773; font-weight:600; margin:0 0 10px 0;">
# <div dir="rtl"
#
#  רגרסיה פולינומית מרחיבה את הרגרסיה הליניארית, היא בעצם הכללה שלה על ידי הוספת חזקות במשתנה המסביר כמשתנים מסבירים נוספים. בדרך זו ניתן להתאים קשרים לא ליניאריים תוך שימוש במסגרת של מודל ליניארי. <br>
# במקום מודל לינארי פשוט :
# $$ y = b_0 + b_1x $$
# ברגרסיה פולינומית מסדר p נכתוב
# $$ Y = \beta_0 + \beta_1x + \beta_2x^2 + \beta_3x^3+ ...b_px^p   $$
#
#   </div>

# %% [markdown]
# <div style="background:#e0f4ff; border:2px solid #0077b6; border-radius:12px; padding:20px 24px;
#             direction:ltr; text-align:right;">
#
#   <h2 style="margin:4px 0 14px 0; font-size:48px; font-weight:700; color:#004c70;">
#     :בקצרה על אינטראקציות שיהיה בשבוע הבא
#   </h2>
#
#   <div style="height:1px; background:#cbeafb; margin:4px 0 18px 0;"></div>
#
# <div dir="rtl"
#   <div style="font-size:22px; color:#0a5773; font-weight:600; margin:0 0 10px 0;">
# <div dir="rtl"
#
# אינטראקציה זה איבר שבו שני משתנים שונים מוכפלים זה בזה. <br>
# למשל אם יש לנו שני משתנים $x_1$  ו- $x_2$: <br>
# **בלי אינטראקציה** - מותר איברים כמו : <br>
# $x_1$ , $x_2^2$, $x_1^3$ ... <br>
#
# <div dir="rtl"
#
# **עם אינטראקציה** - מופיעים גם איברים כמו : <br>
# $x_1x_2$ , $x_1^2x_2$ , $x_1x_2^2$ ... <br>
# כלומר :<br>
# **אינטראקציה** = מכפלה של יותר ממשתנה בסיסי אחד באותו איבר
#   </div>

# %% [markdown]
# <div style="background:#e0f4ff; border:2px solid #0077b6; border-radius:12px; padding:20px 24px;
#             direction:ltr; text-align:right;">
#
#   <h2 style="margin:4px 0 14px 0; font-size:28px; font-weight:700; color:#004c70;">
#    הנתונים שנעבוד איתם היום
#   </h2>
#
#   <div style="height:1px; background:#cbeafb; margin:4px 0 18px 0;"></div>
#
# <div dir="rtl"
#   <div style="font-size:14px; color:#0a5773; font-weight:600; margin:0 0 10px 0;">
# <div dir="rtl"
#
# במחברת הזו נלמד רגרסיה פולינומית על נתונים סינטטיים מעולם הבטיחות.
#
# <div dir="rtl"
#
# הסיפור:
# - יש לנו **מלגזה במחסן**.
# - המשתנה המסביר: מהירות נסיעה של המלגזה בקמ״ש.
# - המשתנה התלוי: מדד סיכון בטיחותי (Risk Index) – ככל שהמדד גבוה יותר, המערכת פחות בטוחה.
#
# <div dir="rtl"
#
# נושאים שנכסה:
# 1. רגרסיה ליניארית פשוטה ובדיקת לינאריות.
# 2. טרנספורמציה על משתנה התגובה (לוג של ה-Risk).
# 3. בניית מודל פולינומי (חזקות של X) ושמירה על מודל ליניארי במקדמים.
# 4. הדגמת Overfitting עם פולינומים מדרגות שונות ופיצול Train/Test.
# 5. שימוש במדדים מענישי־מורכבות (Adjusted R², AIC, BIC) לבחירת דרגת הפולינום.
#
# <div dir="rtl"
#
# הנתונים יהיו סינטטיים, כך שה״אמת״ הסטטיסטית היא **פונקציה פולינומית ממעלה רביעית** של המהירות.

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import statsmodels.api as sm

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

np.random.seed(42)  # for reproducibility
sns.set(style="whitegrid")

# %%
# Number of observations
n = 30

# Forklift speed in km/h, realistic range in a warehouse (0 to ~16 km/h)
speed = np.linspace(0, 30, n)

# Normalize speed around 8 km/h to get values roughly in [-2, 2]
x_norm = (speed - 15) / 7.5

# True underlying safety risk (5th-degree polynomial in x_norm)
# This polynomial has both even and odd powers -> inflection points, non-parabolic shape
true_risk = (
    10
    + 0.5 * x_norm         # linear term
    - 1.5 * x_norm**2      # quadratic term
    + 0.7 * x_norm**3      # cubic term
    + 0.3 * x_norm**4      # 4th-degree term
    - 0.2 * x_norm**5      # 5th-degree term
)

# Add random noise to simulate measurement error / variability
noise = np.random.normal(loc=0, scale=0.5, size=n)

risk = true_risk + noise

# Build DataFrame
df = pd.DataFrame({
    "forklift_speed_kmh": speed,
    "safety_risk_index": risk,
    "true_risk_no_noise": true_risk
})

# %%
df.head()
# Out:
#    forklift_speed_kmh  safety_risk_index  true_risk_no_noise
# 0            0.000000           8.848357            8.600000
# 1            1.034483           7.363311            7.432443
# 2            2.068966           7.113235            6.789391
# 3            3.103448           7.308106            6.546591
# 4            4.137931           6.480296            6.597373

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df["forklift_speed_kmh"], df["safety_risk_index"],
            alpha=0.6, label="Observed risk")

plt.xlabel("Forklift speed (km/h)")
plt.ylabel("Safety risk index")
plt.title("Synthetic safety data: risk vs forklift speed")
plt.legend()
plt.show()

# %% [markdown]
# <div style="background:#e0f4ff; border:2px solid #0077b6; border-radius:12px; padding:20px 24px;
#             direction:ltr; text-align:right;">
#
#   <h2 style="margin:4px 0 14px 0; font-size:30px; font-weight:700; color:#004c70;">
#     ?חלק א': רגרסיה ליניארית פשוטה – האם קו ישר מספיק
#   </h2>
#
#   <div style="height:1px; background:#cbeafb; margin:4px 0 18px 0;"></div>
#
# <div dir="rtl"
#   <div style="font-size:22px; color:#0a5773; font-weight:600; margin:0 0 10px 0;">
# <div dir="rtl"
#
# נבדוק האם קו ישר מתאים לקשר בין מהירות המלגזה למדד הסיכון : <br>
# נבחן:<br>
# 1. תקציר המודל (R², מקדמים).<br>
# 2. איך קו הרגרסיה "יושב" על העקומה האמיתית.<br>
# 3. השאריות – האם יש מבנה (pattern) שמעיד שהמודל לא גמיש מספיק?<br>
#   </div>

# %%
# Simple linear regression: risk ~ speed
X = df[["forklift_speed_kmh"]]
y = df["safety_risk_index"]

X_const = sm.add_constant(X)
model_linear = sm.OLS(y, X_const).fit()

print(model_linear.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:      safety_risk_index   R-squared:                       0.496
# Model:                            OLS   Adj. R-squared:                  0.478
# Method:                 Least Squares   F-statistic:                     27.60
# Date:                Wed, 19 Nov 2025   Prob (F-statistic):           1.39e-05
# Time:                        16:32:27   Log-Likelihood:                -33.059
# No. Observations:                  30   AIC:                             70.12
# Df Residuals:                      28   BIC:                             72.92
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  7.6520      0.269     28.494      0.000       7.102       8.202
# ...

# %%
# Plot data and linear fit
plt.figure(figsize=(8, 6))
plt.scatter(df["forklift_speed_kmh"], df["safety_risk_index"],
            alpha=0.6, label="Data points")

y_pred_linear = model_linear.predict(X_const)

sorted_idx = np.argsort(df["forklift_speed_kmh"])
speed_sorted = df["forklift_speed_kmh"].iloc[sorted_idx]
y_pred_sorted = y_pred_linear.iloc[sorted_idx]

plt.plot(speed_sorted, y_pred_sorted,
         color="red", linewidth=2, label="Linear fit")
plt.plot(df["forklift_speed_kmh"], df["true_risk_no_noise"],
         linewidth=2, label="True risk (no noise)", alpha=0.7)

plt.xlabel("Forklift speed (km/h)")
plt.ylabel("Safety risk index")
plt.title("Linear regression: risk ~ speed")
plt.legend()
plt.show()

# %%
# Residuals plot
residuals_linear = y - y_pred_linear

plt.figure(figsize=(8, 6))
plt.scatter(df["forklift_speed_kmh"], residuals_linear,
            alpha=0.6)
plt.axhline(0, color="black", linestyle="--")
plt.xlabel("Forklift speed (km/h)")
plt.ylabel("Residuals")
plt.title("Residuals vs speed (Linear model)")
plt.show()

# %% [markdown]
# <div style="background:#e0f4ff; border:2px solid #0077b6; border-radius:12px; padding:20px 24px;
#             direction:ltr; text-align:right;">
#
#   <h2 style="margin:4px 0 14px 0; font-size:30px; font-weight:700; color:#004c70;">
#     חלק ב': טרנספורמציה על משתנה המטרה - תרגיל כיתה
#   </h2>
#
#   <div style="height:1px; background:#cbeafb; margin:4px 0 18px 0;"></div>
#
# <div dir="rtl"
#   <div style="font-size:22px; color:#0a5773; font-weight:600; margin:0 0 10px 0;">
# <div dir="rtl"
#
# הציעו טרנספורמציה כלשהי עבור $y$ במטרה לקבל תוצאות ניבוי ומודל יציב יותר ממודל רגרסיה הפשוט שיצרנו למעלה : <br>
# <br>
# הציגו:<br>
# 1. תקציר המודל (R², מקדמים).<br>
# 2. איך קו הרגרסיה "יושב" על העקומה האמיתית.<br>
# 3. השאריות – האם יש מבנה (pattern) שמעיד שהמודל לא גמיש מספיק?<br>
#   </div>

# %% [markdown]
# ## 1. תקציר המודל (R², מקדמים)

# %%
# log of risk (strictly positive)
df["log_risk"] = np.log(df["safety_risk_index"])

X = df[["forklift_speed_kmh"]]
y_log = df["log_risk"]

X_const = sm.add_constant(X)
model_log = sm.OLS(y_log, X_const).fit()

print(model_log.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               log_risk   R-squared:                       0.495
# Model:                            OLS   Adj. R-squared:                  0.477
# Method:                 Least Squares   F-statistic:                     27.50
# Date:                Wed, 19 Nov 2025   Prob (F-statistic):           1.43e-05
# Time:                        15:40:41   Log-Likelihood:                 30.611
# No. Observations:                  30   AIC:                            -57.22
# Df Residuals:                      28   BIC:                            -54.42
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  2.0299      0.032     63.121      0.000       1.964       2.096
# ...

# %% [markdown]
# ## 2. איך קו הרגרסיה "יושב" על העקומה האמיתית

# %% [markdown]
# ## 3. השאריות – האם יש מבנה (pattern) שמעיד שהמודל לא גמיש מספיק?

# %% [markdown]
# <div style="background:#e0f4ff; border:2px solid #0077b6; border-radius:12px; padding:20px 24px;
#             direction:ltr; text-align:right;">
#
#   <h2 style="margin:4px 0 14px 0; font-size:30px; font-weight:700; color:#004c70;">
#     חלק ג': רגרסיה פולינומית
#   </h2>
#
#   <div style="height:1px; background:#cbeafb; margin:4px 0 18px 0;"></div>
#
# <div dir="rtl"
#   <div style="font-size:22px; color:#0a5773; font-weight:600; margin:0 0 10px 0;">
# <div dir="rtl"
#
#
#   </div>

# %%
# Function to highlight maximum in red
def highlight_max_red(s):
    is_max = s == s.max()
    return ['color: red' if v else '' for v in is_max]

# Function to highlight minimum in red
def highlight_min_red(s):
    is_min = s == s.min()
    return ['color: red' if v else '' for v in is_min]

# %% [markdown]
# <div dir="rtl">
#
#
#
# ### נתחיל עבור Degree = 1
#
# ### נחלק בין train לtest:

# %%
X = df[["forklift_speed_kmh"]].values
y = df["safety_risk_index"].values

X = X.reshape(-1, 1) # -1 = Let NumPy calculate how many rows you need on its own.
y = y.reshape(-1, 1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
poly = PolynomialFeatures(degree=1)
X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.transform(X_test)

X_train_poly[:5,:], X_test_poly[:5,:]
# Out:
# (array([[ 1.        ,  0.        ],
#         [ 1.        ,  4.13793103],
#         [ 1.        , 16.55172414],
#         [ 1.        ,  5.17241379],
#         [ 1.        , 13.44827586]]),
#  array([[ 1.        , 27.93103448],
#         [ 1.        , 15.51724138],
#         [ 1.        , 23.79310345],
#         [ 1.        , 17.5862069 ],
#         [ 1.        ,  8.27586207]]))

# %% [markdown]
# <div dir="rtl">
#
#
# ## נבנה מודל:

# %%
model = sm.OLS(y_train, X_train_poly).fit()
y_pred_test = model.predict(X_test_poly)
y_pred_train = model.predict(X_train_poly)

# %% [markdown]
# <div dir="rtl">
#
#
# ## נחשב מדדים:

# %%
df_sum = pd.DataFrame([])
deg = 1
X_train_poly = poly.fit_transform(X_train)
X_test_poly = poly.transform(X_test)
model = sm.OLS(y_train, X_train_poly).fit()
y_pred_test = model.predict(X_test_poly)
y_pred_train = model.predict(X_train_poly)
mse_test = ((y_pred_test - y_test[:,0])**2).mean()
mse_train = ((y_pred_train - y_train[:,0])**2).mean()
curr_ind = df_sum.shape[0]
df_sum.loc[curr_ind, 'degree'] = deg
df_sum.loc[curr_ind, 'MSE_test'] = mse_test
df_sum.loc[curr_ind, 'MSE_train'] = mse_train
df_sum.loc[curr_ind, '$R^2$'] = model.rsquared


df_sum.sort_values(by = 'MSE_test')
# Out:
#    degree  MSE_test  MSE_train     $R^2$
# 0     1.0  0.583897   0.523227  0.565106

# %%
model.rsquared_adj
# Out:
# np.float64(0.5422171412200723)

# %%
df_sum = pd.DataFrame([])

for deg in range(1,11):
    poly = PolynomialFeatures(degree=deg)
    X_train_poly = poly.fit_transform(X_train)
    X_test_poly = poly.transform(X_test)
    model = sm.OLS(y_train, X_train_poly).fit()
    y_pred_test = model.predict(X_test_poly)
    y_pred_train = model.predict(X_train_poly)
    mse_test = ((y_pred_test - y_test[:,0])**2).mean()
    mse_train = ((y_pred_train - y_train[:,0])**2).mean()
    curr_ind = df_sum.shape[0]
    df_sum.loc[curr_ind, 'degree'] = deg
    df_sum.loc[curr_ind, 'MSE_test'] = mse_test
    df_sum.loc[curr_ind, 'MSE_train'] = mse_train
    df_sum.loc[curr_ind, '$R^2$'] = model.rsquared


df_sum.sort_values(by = 'MSE_test')
# Out:
#    degree  MSE_test  MSE_train     $R^2$
# 4     5.0  0.187080   0.140594  0.883142
# 3     4.0  0.253841   0.190605  0.841574
# 1     2.0  0.279344   0.431320  0.641497
# 5     6.0  0.321350   0.101198  0.915886
# 7     8.0  0.352483   0.097717  0.918780
# 6     7.0  0.397303   0.098313  0.918285
# 2     3.0  0.411442   0.259094  0.784647
# 8     9.0  0.423837   0.097109  0.919285
# 0     1.0  0.583897   0.523227  0.565106
# 9    10.0  0.598349   0.108179  0.910084

# %%
for deg in range(1,11):
    poly = PolynomialFeatures(degree=deg)
    X_train_poly = poly.fit_transform(X)
    model = sm.OLS(y, X_train_poly).fit()
    
    y_pred_train = model.predict(X_train_poly)
    
    rss = ((y_pred_train - y[:,0])**2).sum()
    curr_ind = df_sum.shape[0]
    df_sum.loc[deg-1, 'degree'] = deg
    
    df_sum.loc[deg-1, 'aic'] = model.aic
    df_sum.loc[deg-1, 'bic'] = model.bic
    df_sum.loc[deg-1, '$R^2_{adj}$'] = model.rsquared_adj
    df_sum.loc[deg-1, '$R^2$'] = model.rsquared
    df_sum.loc[deg-1, 'rss'] = rss

df_sum
# Out:
#    degree  MSE_test  MSE_train     $R^2$        aic        bic  $R^2_{adj}$  \
# 0     1.0  0.583897   0.523227  0.496372  70.117259  72.919654     0.478385
# 1     2.0  0.279344   0.431320  0.643312  61.767935  65.971527     0.616891
# 2     3.0  0.411442   0.259094  0.731029  55.300259  60.905048     0.699994
# 3     4.0  0.253841   0.190605  0.816638  45.806022  52.812009     0.787300
# 4     5.0  0.187080   0.140594  0.865219  38.571605  46.978790     0.837140
# 5     6.0  0.321350   0.101198  0.871699  39.093578  48.901959     0.838229
# 6     7.0  0.397303   0.098313  0.874648  40.395805  51.605385     0.834764
# 7     8.0  0.352483   0.097717  0.879557  41.197507  53.808284     0.833673
# 8     9.0  0.423837   0.097109  0.879565  43.195315  57.207289     0.825370
# 9    10.0  0.598349   0.108179  0.863812  44.883264  57.494040     0.811930
#
#          rss
# 0  15.914473
# 1  11.271208
# 2   8.499400
# 3   5.794182
# 4   4.259026
# 5   4.054279
# 6   3.961069
# 7   3.805969
# ...

# %%
styled_df = df_sum.style.apply(highlight_max_red, subset=[ '$R^2_{adj}$','$R^2$']) \
                    .apply(highlight_min_red, subset=['aic', 'bic','rss', 'MSE_test', 'MSE_train'])

styled_df
# Out:
# <style type="text/css">
# #T_c72b1_row4_col1, #T_c72b1_row4_col4, #T_c72b1_row4_col5, #T_c72b1_row5_col6, #T_c72b1_row8_col2, #T_c72b1_row8_col3, #T_c72b1_row8_col7 {
#   color: red;
# }
# </style>
# <table id="T_c72b1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c72b1_level0_col0" class="col_heading level0 col0" >degree</th>
#       <th id="T_c72b1_level0_col1" class="col_heading level0 col1" >MSE_test</th>
#       <th id="T_c72b1_level0_col2" class="col_heading level0 col2" >MSE_train</th>
#       <th id="T_c72b1_level0_col3" class="col_heading level0 col3" >$R^2$</th>
#       <th id="T_c72b1_level0_col4" class="col_heading level0 col4" >aic</th>
#       <th id="T_c72b1_level0_col5" class="col_heading level0 col5" >bic</th>
#       <th id="T_c72b1_level0_col6" class="col_heading level0 col6" >$R^2_{adj}$</th>
#       <th id="T_c72b1_level0_col7" class="col_heading level0 col7" >rss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
plt.figure()
plt.plot(df_sum['degree'], df_sum['aic'], label = 'AIC')
plt.plot(df_sum['degree'], df_sum['bic'], label = 'BIC')
plt.xlabel('Degree')
plt.ylabel('Measure')
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(df_sum['degree'], df_sum['$R^2_{adj}$'], label = '$R^2_{adj}$')
plt.plot(df_sum['degree'], df_sum['$R^2$'], label = '$R^2$')

plt.xlabel('Degree')
plt.ylabel('Measure')
plt.legend()
plt.show()

# %%
# אם ipywidgets לא מותקן:
# !pip install ipywidgets

import numpy as np
import matplotlib.pyplot as plt

import ipywidgets as widgets
from ipywidgets import interact

# %%
def adjusted_r2(R2, n, k):
    """
    Compute Adjusted R^2 given:
    R2 - regular R^2
    n  - number of observations
    k  - number of predictors (without intercept)
    """
    return 1 - ((1 - R2) * (n - 1) / (n - k - 1))

# %%
def plot_adjusted_r2_vs_k(R2=0.91, n=30, max_k=15):
    """
    Plot Adjusted R^2 as a function of k, for fixed R2 and n.
    """
    # k must be < n - 1 to avoid division by zero in the formula
    k_values = np.arange(1, max_k + 1)
    k_values = k_values[k_values < n - 1]

    R2_adj_values = adjusted_r2(R2, n, k_values)

    plt.figure(figsize=(8, 5))
    plt.plot(k_values, R2_adj_values, marker='o')
    plt.ylim(0, 1)
    plt.xlabel("k (number of predictors)")
    plt.ylabel("Adjusted R²")
    plt.title(f"Adjusted R² as a function of k\n(R² = {R2:.2f}, n = {n})")
    plt.grid(True)
    plt.show()

    # Display current Adjusted R² for the largest k in the range
    if len(k_values) > 0:
        k_current = k_values[-1]
        R2_adj_current = adjusted_r2(R2, n, k_current)
        print(f"For k = {k_current}, n = {n}, R² = {R2:.2f} → Adjusted R² = {R2_adj_current:.4f}")


interact(
    plot_adjusted_r2_vs_k,
    R2=widgets.FloatSlider(
        min=0.1, max=0.99, step=0.01, value=0.918552,  # 5	0.918552 0.901584
        description='R²'
    ),
    n=widgets.IntSlider(
        min=5, max=200, step=1, value=30,
        description='n'
    ),
    max_k=widgets.IntSlider(
        min=1, max=20, step=1, value=10,
        description='max k'
    )
);
# Out:
# interactive(children=(FloatSlider(value=0.918552, description='R²', max=0.99, min=0.1, step=0.01), IntSlider(v…

# %% [markdown]
# ### $$ R^2_{\text{adj}} = 1 - \left( \frac{(1 - R^2)(n - 1)}{n - k - 1} \right) $$

# %%
def plot_adjusted_r2_vs_n(R2=0.8, k=3, n_max=200):
    """
    Plot Adjusted R^2 as a function of n, for fixed R2 and k.
    """
    # n must be > k + 1 (otherwise denominator n - k - 1 <= 0)
    n_values = np.arange(k + 2, n_max + 1)
    R2_adj_values = adjusted_r2(R2, n_values, k)

    plt.figure(figsize=(8, 5))
    plt.plot(n_values, R2_adj_values, marker='o')
    plt.ylim(0, 1)
    plt.xlabel("n (number of observations)")
    plt.ylabel("Adjusted R²")
    plt.title(f"Adjusted R² as a function of n\n(R² = {R2:.2f}, k = {k})")
    plt.grid(True)
    plt.show()

    # Display Adjusted R² for the largest n
    if len(n_values) > 0:
        n_current = n_values[-1]
        R2_adj_current = adjusted_r2(R2, n_current, k)
        print(f"For n = {n_current}, k = {k}, R² = {R2:.2f} → Adjusted R² = {R2_adj_current:.4f}")


interact(
    plot_adjusted_r2_vs_n,
    R2=widgets.FloatSlider(
        min=0.1, max=0.99, step=0.01, value=0.92,
        description='R²'
    ),
    k=widgets.IntSlider(
        min=1, max=15, step=1, value=3,
        description='k'
    ),
    n_max=widgets.IntSlider(
        min=20, max=500, step=5, value=200,
        description='max n'
    )
);
# Out:
# interactive(children=(FloatSlider(value=0.92, description='R²', max=0.99, min=0.1, step=0.01), IntSlider(value…

# %% [markdown]
# ### $$ R^2_{\text{adj}} = 1 - \left( \frac{(1 - R^2)(n - 1)}{n - k - 1} \right) $$
